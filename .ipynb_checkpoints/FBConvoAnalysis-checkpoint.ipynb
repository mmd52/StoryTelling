# %% [markdown]
# ## @ Author Mohammed
# ### Data storyt Telling - FACEBOOK AND THE CAMBRIDGE ANALYTICA SCAM
# #### Date 28/04/2018

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk.corpus as corpus
import nltk

from bokeh.layouts import layout
from bokeh.layouts import widgetbox

from bokeh.embed import file_html

from bokeh.io import show
from bokeh.io import output_notebook 

from bokeh.models import Text
from bokeh.models import Plot
from bokeh.models import Slider
from bokeh.models import Circle
from bokeh.models import Range1d
from bokeh.models import CustomJS
from bokeh.models import HoverTool
from bokeh.models import LinearAxis
from bokeh.models import ColumnDataSource
from bokeh.models import SingleIntervalTicker
from bokeh.charts import Line
from bokeh.plotting import figure

from bokeh.palettes import Spectral6
from bokeh.charts import Bar

output_notebook()
# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e1fac741-f6b7-47d3-8377-078fe369d93b">Loading BokehJS ...</span>
#     </div>

# %%
df=pd.read_csv('mark.csv')

# %%
df.shape
# Out:
# (858, 2)

# %%
df.head()
# Out:
#         Person                                               Text
# 0    GRASSLEY:   I'll start with you.\n\nFacebook handles exte...
# 1  ZUCKERBERG:   Mr. Chairman, thank you.\n\nAs I mentioned, w...
# 2    GRASSLEY:   OK (ph).\n\nHave you ever required an audit t...
# 3  ZUCKERBERG:   Mr. Chairman, yes we have. I don't have the e...
# 4    GRASSLEY:   I was going to assume that, sitting here toda...

# %%
plt.figure(figsize=(10,5))
df['Person'].value_counts().plot.bar()

# %%
def get_count(x):
    return len(nltk.word_tokenize(x))
df['len']=df['Text'].map(get_count)

# %%
df.head()
# Out:
#         Person                                               Text  len
# 0    GRASSLEY:   I'll start with you.\n\nFacebook handles exte...  139
# 1  ZUCKERBERG:   Mr. Chairman, thank you.\n\nAs I mentioned, w...  166
# 2    GRASSLEY:   OK (ph).\n\nHave you ever required an audit t...   29
# 3  ZUCKERBERG:   Mr. Chairman, yes we have. I don't have the e...  143
# 4    GRASSLEY:   I was going to assume that, sitting here toda...   55

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
ENGLISH_STOP_WORDS = frozenset([
    "a", "about", "above", "across", "after", "afterwards", "again", "against",
    "all", "almost", "alone", "along", "already", "also", "although", "always",
    "am", "among", "amongst", "amoungst", "amount", "an", "and", "another",
    "any", "anyhow", "anyone", "anything", "anyway", "anywhere", "are",
    "around", "as", "at", "back", "be", "became", "because", "become",
    "becomes", "becoming", "been", "before", "beforehand", "behind", "being",
    "below", "beside", "besides", "between", "beyond", "bill", "both",
    "bottom", "but", "by", "call", "can", "cannot", "cant", "co", "con",
    "could", "couldnt", "cry", "de", "describe", "detail", "do", "done",
    "down", "due", "during", "each", "eg", "eight", "either", "eleven", "else",
    "elsewhere", "empty", "enough", "etc", "even", "ever", "every", "everyone",
    "everything", "everywhere", "except", "few", "fifteen", "fifty", "fill",
    "find", "fire", "first", "five", "for", "former", "formerly", "forty",
    "found", "four", "from", "front", "full", "further", "get", "give", "go",
    "had", "has", "hasnt", "have", "he", "hence", "her", "here", "hereafter",
    "hereby", "herein", "hereupon", "hers", "herself", "him", "himself", "his",
    "how", "however", "hundred", "i", "ie", "if", "in", "inc", "indeed",
    "interest", "into", "is", "it", "its", "itself", "keep", "last", "latter",
    "latterly", "least", "less", "ltd", "made", "many", "may", "me",
    "meanwhile", "might", "mill", "mine", "more", "moreover", "most", "mostly",
    "move", "much", "must", "my", "myself", "name", "namely", "neither",
    "never", "nevertheless", "next", "nine", "no", "nobody", "none", "noone",
    "nor", "not", "nothing", "now", "nowhere", "of", "off", "often", "on",
    "once", "one", "only", "onto", "or", "other", "others", "otherwise", "our",
    "ours", "ourselves", "out", "over", "own", "part", "per", "perhaps",
    "please", "put", "rather", "re", "same", "see", "seem", "seemed",
    "seeming", "seems", "serious", "several", "she", "should", "show", "side",
    "since", "sincere", "six", "sixty", "so", "some", "somehow", "someone",
    "something", "sometime", "sometimes", "somewhere", "still", "such",
    "system", "take", "ten", "than", "that", "the", "their", "them",
    "themselves", "then", "thence", "there", "thereafter", "thereby",
    "therefore", "therein", "thereupon", "these", "they", "thick", "thin",
    "third", "this", "those", "though", "three", "through", "throughout",
    "thru", "thus", "to", "together", "too", "top", "toward", "towards",
    "twelve", "twenty", "two", "un", "under", "until", "up", "upon", "us",
    "very", "via", "was", "we", "well", "were", "what", "whatever", "when",
    "whence", "whenever", "where", "whereafter", "whereas", "whereby",
    "wherein", "whereupon", "wherever", "whether", "which", "while", "whither",
    "who", "whoever", "whole", "whom", "whose", "why", "will", "with",
    "within", "without", "would", "yet", "you", "your", "yours", "yourself",
    "yourselves","thank","you","mr","zuckerberg","chairman"])

# %%
stopwords=set(STOPWORDS).union(ENGLISH_STOP_WORDS)
#alice_mask = np.array(Image.open("../input/fbmask/fbmask.png"))
names = df["Text"]
#print(names)
wordcloud = WordCloud(max_words=150,stopwords=stopwords,max_font_size=70, width=800, height=300,#mask=alice_mask,
                      background_color ="white").generate(' '.join(names))
plt.figure(figsize=(15,8))
plt.imshow(wordcloud,interpolation="bilinear")
plt.title("Zuckerberg Testimony", fontsize=30)
plt.axis("off")
plt.savefig("ZuckerbergTestimony.png",dpi=600)
plt.savefig('WordCloud.jpg')
plt.show()

# %%
print("The total words spoken by Mark were {} words".format(df.query("Person=='ZUCKERBERG:'")['len'].sum()))
print("The average length of his response was {} words".format(round(df.query("Person=='ZUCKERBERG:'")['len'].mean(),2)))
print("The maximum length of Mark's response was {} words".format(df.query("Person=='ZUCKERBERG:'")['len'].max()))
# Out:
# The total words spoken by Mark were 19959 words
# The average length of his response was 51.71 words
# The maximum length of Mark's response was 524 words

# %%
a=df.query("Person !='ZUCKERBERG:'").groupby("Person").sum().rename(columns={'len':'Total Words'}).sort_values("Total Words",ascending=False).head(20)
a.index.astype(list)
# Out:
# Index(['GRASSLEY:', 'THUNE:', 'TILLIS:', 'MASTO:', 'BOOKER:', 'FISCHER:',
#        'TESTER:', 'SULLIVAN:', 'HASSAN:', 'PETERS:', 'GARDNER:', 'MARKEY:',
#        'KENNEDY:', 'HIRONO:', 'CAPITO:', 'SASSE:', 'GRAHAM:', 'HARRIS:',
#        'BALDWIN:', 'YOUNG:'],
#       dtype='object', name='Person')

# %%
xdr = ['GRASSLEY', 'THUNE', 'TILLIS', 'MASTO', 'BOOKER', 'FISCHER',
       'TESTER', 'SULLIVAN', 'HASSAN', 'PETERS', 'GARDNER', 'MARKEY',
       'KENNEDY', 'HIRONO', 'CAPITO', 'SASSE', 'GRAHAM', 'HARRIS',
       'BALDWIN', 'YOUNG']
ydr = Range1d(100, 2000)
plot = figure(
    x_range=xdr,
    y_range=ydr,
    plot_width=1100,
    plot_height=500,
    outline_line_color=None,
    toolbar_location=None, 
    min_border=20,
    x_axis_label='Senators' ,
    y_axis_label='Words Spoken'
)

plot.vbar(x=xdr,top=a['Total Words'],width=1,line_color="white",fill_color='#0000B2')
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5e0cfa65-d30f-4989-82d3-b05e34e9a8d6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5e0cfa65-d30f-4989-82d3-b05e34e9a8d6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5e0cfa65-d30f-4989-82d3-b05e34e9a8d6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5e0cfa65-d30f-4989-82d3-b05e34e9a8d6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a1ed9185-649e-43b1-9f84-48e8dc39c93e":{"roots":{"references":[{"attributes":{"axis_label":"Senators","formatter":{"id":"b6511312-ee66-4c92-b7f0-73afd15205a0","type":"CategoricalTickFormatter"},"plot":{"id":"1aea4b63-e2f5-4835-bb80-3315e1cbf71d","subtype":"Figure","type":"Plot"},"ticker":{"id":"c
type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8078acc6-4740-4cd0-a420-134f5deea388","type":"VBar"},"selection_glyph":null},"id":"54bdc5d4-f7d3-4ee6-9eac-abc44c8fb53e","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3443481e-fb20-40ec-bfab-6ccde62c74c1","type":"PanTool"},{"id":"c7b4fcd9-57e5-496f-911e-5992374f95cc","type":"WheelZoomTool"},{"id":"77aca1c8-ee0f-4f58-9fac-bb3ac8e82e2e","type":"BoxZoomTool"},{"id":"dffc7347-de58-4d40-8ce7-96a813680c59","type":"SaveTool"},{"id":"7add9120-c751-4fda-a156-89829ee3fe43","type":"ResetTool"},{"id":"a60 ...

# %% [markdown]
# #### Restart Kernel after this

# %%
from sklearn.feature_extraction import text
def get_imp(bow,mf,ngram):
    tfidf=text.CountVectorizer(bow,ngram_range=(ngram,ngram),max_features=mf,stop_words=ENGLISH_STOP_WORDS)
    matrix=tfidf.fit_transform(bow)
    return pd.Series(np.array(matrix.sum(axis=0))[0],index=tfidf.get_feature_names()).sort_values(ascending=False).head(100)

# %% [markdown]
# #### What is mark telling the senate and the world

# %%
mark=df[df['Person']=="ZUCKERBERG:"]['Text'].tolist()
a=get_imp(mark,mf=5000,ngram=3).head(10).sort_values(ascending=True)
a.index
# Out:
# Index(['single app access', 'sign app bring', 'working security content',
#        'going 20 000', 'foreign interference elections', 'app access large',
#        'security content review', 'senator don know', '20 000 people',
#        'want make sure'],
#       dtype='object')

# %%
xdr = ['single app access', 'sign app bring', 'working security content',
       'going 20 000', 'foreign interference elections', 'app access large',
       'security content review', 'senator don know', '20 000 people',
       'want make sure']
ydr = Range1d(0, 8)
plot2 = figure(
    x_range=ydr,
    y_range=xdr,
    plot_width=1100,
    plot_height=500,
    outline_line_color=None,
    toolbar_location=None, 
    min_border=20,
    x_axis_label='Number of times' ,
    y_axis_label='What Mark Said in 3 words'
)

plot2.hbar(right=a.values,y=xdr,height=0.5,line_color="white",fill_color='#0000B2')
show(plot2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="48f5ab88-49bc-4b42-a008-fbb84003eaad"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("48f5ab88-49bc-4b42-a008-fbb84003eaad");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("48f5ab88-49bc-4b42-a008-fbb84003eaad");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '48f5ab88-49bc-4b42-a008-fbb84003eaad' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2b86fde7-fb06-4c54-801c-fad8c4a223c7":{"roots":{"references":[{"attributes":{"plot":{"id":"e33e0063-fa2d-4c05-bcd3-4003f2bad4cf","subtype":"Figure","type":"Plot"}},"id":"41813955-f6dc-492e-9ec9-347a07abd2ee","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"2c95639b-8c60-4f0c-a5d8-d1e21f246613","type":"HBar"},{"attributes":{"dimension":1,"plot":{"id":"e33e0063-fa2d-4c05-bcd3-4003f2bad4cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"c034a009-ed68-4489-ae20-68d235027f0b","type":"CategoricalTicker"}},"id":"c1a2a63b-1633-40bd-aafe-ae37848b7039","type":"Grid"},{"attributes":{"callback":null,"column_names":["y","right"],"data":{"right":[3,3,4,4,4,4,5,5,5,8],"y":["single app access","sign app bring","working security content","going 20 000","foreign interference elections","app access large","security content review","senator don know","20 000 people","want make sure"]}},"id":"14a71c61-2baa-48a6-b9dd-8ceb88db028d","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"e33e0063-fa2d-4c05-bcd3-4003f2bad4cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"07fa772d-5a9c-49d7-8c7e-50cc130e7fc9","type":"BasicTicker"}},"id":"736b4a94-1c10-43e7-bcd7-324f13508c98","type":"Grid"},{"attributes":{"axis_label":"Number of times","formatter":{"id":"6f00b87f-0a4f-4b85-af29-528e8862002a","type":"BasicTickFormatter"},"plot":{"id":"e33e0063-fa2d-4c05-bcd3-4003f2bad4cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"07fa772d-5a9c-49d7-8c7e-50cc130e7fc9","type":"BasicTicker"}},"id":"bc8efde9-0f2e-41b5-93af-e2ac0b9880e5","type":"LinearAxis"},{"attributes":{"overlay":{"id":"302a9111-5687-40e2-a095-506d459bfcf4","type":"BoxAnnotation"},"plot":{"id":"e33e0063-fa2d-4c05-bcd3-4003f2bad4cf","subtype":"Figure","type":"Plot"}},"id":"71d408cf-8408-49ad-89eb-b5bb92379082","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":
type":"Toolbar"},{"attributes":{"fill_color":{"value":"#0000B2"},"height":{"value":1},"line_color":{"value":"white"},"right":{"field":"right"},"y":{"field":"y"}},"id":"fcf34a2a-cf4a-4cd7-bbd2-a09818ea3ff4","type":"HBar"},{"attributes":{},"id":"c034a009-ed68-4489-ae20-68d235027f0b","type":"CategoricalTicker"},{"attributes":{},"id":"6f00b87f-0a4f-4b85-af29-528e8862002a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e33e0063-fa2d-4c05-bcd3-4003f2bad4cf","subtype":"Figure","type":"Plot"}},"id":"f7291f8b-b6b3-4c20-a189-314ca76fbe8f","type":"ResetTool"},{"attributes":{},"id":"8d4994d0-a1f6-4654-bfe4-b52284ebe943","type":"ToolEvents"},{"attributes":{},"id":"07fa772d-5a9c-49d7-8c7e-50cc130e7fc9","type":"BasicTicker"},{"attributes":{"plot":{"id":"e33e0063-fa2d-4c05-bcd3-4003f2bad4cf","subtype":"Figure","type":"Plot"}},"id":"af136db2-f1e6-4171-a8a0-4ca0a32a519d","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"302a9111-5687-40e2-a095-506d459bfcf4","type":"BoxAnnotation"},{"attributes":{"callback":null,"factors":["single app access","sign app bring","working security content","going 20 000","foreign interference elections","app access large","security cont ...

# %%
a=get_imp(mark,mf=5000,ngram=2).head(10).sort_values(ascending=True)
a.index
# Out:
# Index(['app developer', 'team follow', 'making sure', 'don know',
#        'senator don', 'senator yes', 'cambridge analytica', 'yes senator',
#        'senator think', 'make sure'],
#       dtype='object')

# %%
xdr = ['app developer', 'team follow', 'making sure', 'don know',
       'senator don', 'senator yes', 'cambridge analytica', 'yes senator',
       'senator think', 'make sure']
ydr = Range1d(0, 40)
plot3 = figure(
    x_range=ydr,
    y_range=xdr,
    plot_width=1100,
    plot_height=500,
    outline_line_color=None,
    toolbar_location=None, 
    min_border=20,
    x_axis_label='Number of times' ,
    y_axis_label='What Mark Said in 2 words'
)

plot3.hbar(right=a.values,y=xdr,height=1,line_color="white",fill_color='#0000B2')
show(plot3)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="71bc02f4-571b-4b61-b0e7-280d125e4078"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("71bc02f4-571b-4b61-b0e7-280d125e4078");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("71bc02f4-571b-4b61-b0e7-280d125e4078");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '71bc02f4-571b-4b61-b0e7-280d125e4078' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6c2666ee-7a59-4323-8473-d23f4593b1c2":{"roots":{"references":[{"attributes":{"plot":{"id":"352fbf70-bb94-43a2-9754-747bc9010ac1","subtype":"Figure","type":"Plot"}},"id":"5257de00-001f-491f-b87b-3ce1f796efd7","type":"HelpTool"},{"attributes":{},"id":"3f797a2b-a59a-4bf6-b0b5-eacb7c3710d9","type":"ToolEvents"},{"attributes":{"plot":null,"text":""},"id":"09007f54-1dc8-4a4d-95b3-7757d2ed4b08","type":"Title"},{"attributes":{"fill_color":{"value":"#0000B2"},"height":{"value":1},"line_color":{"value":"white"},"right":{"field":"right"},"y":{"field":"y"}},"id":"fa1ff71d-4ea8-4266-a2be-b41f69432f31","type":"HBar"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"742a0816-0b73-4f1a-b65c-ed65f1ec16fd","type":"PanTool"},{"id":"1ab3c114-07fb-4fa9-b371-9ef222c9d9b2","type":"WheelZoomTool"},{"id":"ef12d6fa-3a94-4c89-9ed8-8bfd975f7e4a","type":"BoxZoomTool"},{"id":"95bd831d-bf0a-4695-a0cb-29a8f5946bc3","type":"SaveTool"},{"id":"a8a2e3dd-1c0f-4586-a11c-4e3919249649","type":"ResetTool"},{"id":"5257de00-001f-491f-b87b-3ce1f796efd7","type":"HelpTool"}]},"id":"e92d6e27-39b7-43b0-a4ae-7940c973199c","type":"Toolbar"},{"attributes":{"overlay":{"id":"1948b26a-bf26-4f29-a8ef-2a3b98ee16f1","type":"BoxAnnotation"},"plot":{"id":"352fbf70-bb94-43a2-9754-747bc9010ac1","subtype":"Figure","type":"Plot"}},"id":"ef12d6fa-3a94-4c89-9ed8-8bfd975f7e4a","type":"BoxZoomTool"},{"attributes":{"callback":null,"factors":["app developer","team follow","making sure","don know","senator don","senator yes","cambridge analytica","yes senator","senator think","make sure"]},"id":"e830bfea-c0e8-4e53-b97b-eb50676db942","type":"FactorRange"},{"attributes":{"plot":{"id":"352fbf70-bb94-43a2-9754-747bc9010ac1","subtype":"Figure","type":"Plot"}},"id":"1ab3c114-07fb-4fa9-b371-9ef222c9d9b2","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","right"],"data":{"right":[10,11,11,11,12,14,17,18,29,31],"y":["app developer","team follow","making sure","don know","senator don","senator yes","cambridge analytica","yes senator","senator think","make sure"]}},"id":"b0796f02-db9a-470b-bfef-65a73075b016","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"352fbf70-bb94-43a2-9754-747bc9010ac1","subtype":"Figure","type":"Plot"}},"id":"742a0816-0b73-4f1a-b65c-ed65f1ec16fd","type":"PanTool"},{"attributes":{"callback":null,"end":40},"id":"fbc48f7d-7eca-44a7-8c4b-d69ec289b626","type":"Range1d"},{"attributes":{"below":[{"id":"cb4a115e-0437-422f-988d-9fd8386ff53a","type":"LinearAxis"}],"left":[{"id":"0e0ca1f6-b116-4f2b-bf18-6190efb9a4de","type":"CategoricalAxis"}],"min_border":20,"outline_line_color":{"value":null},"plot_height":500,"plot_width":1100,"renderers":[{"id":"cb4a115e-0437-422f-988d-9fd8386ff53a","type":"LinearAxis"},{"id":"2aaeadc6-6f5d-42cb-b75f-b888b0f660cd","type":"Grid"},{"id":"0e0ca1f6-b116-4f2b-bf18-6190efb9a4de","type":"CategoricalAxis"},{"id":"5674e1d5-8f3c-4ca0-ad85-f4e20bc67ea4","type":"Grid"},{"id":"1948b26a-bf26-4f29-a8ef-2a3b98ee16f1","type":"BoxAnnotation"},{"id":"3c8409c6-cd76-4edb-a3cd-3192fd9ab77d","type":"GlyphRenderer"}],"title":{"id":"09007f54-1dc8-4a4d-95b3-7757d2ed4b08","type":"Title"},"tool_events":{"id":"3f797a2b-a59a-4bf6-b0b5-eacb7c3710d9","type":"ToolEvents"},"toolbar":{"id":"e92d6e27-39b7-43b0-a4ae-7940c973199c","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"fbc48f7d-7eca-44a7-8c4b-d69ec289b626","type":"Range1d"},"y_range":{"id":"e830bfea-c0e8-4e53-b97b-eb50676db942","type":"FactorRange"}},"id":"352fbf70-bb94-43a2-9754-747bc9010ac1","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1948b26a-bf26-4f29-a8ef-2a3b98ee16f1","type":"BoxAnnotation"},{"attribut ...

# %%
get_imp(mark,mf=5000,ngram=1).head(10).sort_values(ascending=True).plot(kind="barh",figsize=(7,7))

# %% [markdown]
# #### Senator Grassley spoke a lot

# %%
w=df[df['Person']=="GRASSLEY:"]['Text'].tolist()
a=get_imp(w,mf=5000,ngram=3).head(10).sort_values(ascending=True)
a.index
# Out:
# Index(['year did actively', 'gave keys didn', 'friends policy does',
#        'free involves trade', 'foundation internet economy',
#        'force chair said', 'senator wicker senator',
#        'privacy protections consumers', 'don charge access',
#        'entire internet ecosystem'],
#       dtype='object')

# %%
xdr = ['year did actively', 'gave keys didn', 'friends policy does',
       'free involves trade', 'foundation internet economy',
       'force chair said', 'senator wicker senator',
       'privacy protections consumers', 'don charge access',
       'entire internet ecosystem']
ydr = Range1d(0, 3)
plot4 = figure(
    x_range=ydr,
    y_range=xdr,
    plot_width=1100,
    plot_height=500,
    outline_line_color=None,
    toolbar_location=None, 
    min_border=20,
    x_axis_label='Number of times' ,
    y_axis_label='
","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"88a4d11f-d168-4a4e-83e6-41581b4a3609","subtype":"Figure","type":"Plot"}},"id":"6978b92a-faba-4d08-96a0-aca55ed23b48","type":"SaveTool"},{"attributes":{"data_source":{"id":"12e10e23-04b1-436f-a ...

# %%
get_imp(w,mf=5000,ngram=2).head(10).sort_values(ascending=True).plot(kind="barh",figsize=(7,7))

# %% [markdown]
# #### In Combination what do all senators want to say!!!!

# %%
S=df[(df['Person']=="CRUZ:")|(df['Person']=="WHITEHOUSE:")|(df['Person']=="WHITEHOUSE:")|(df['Person']=="SCHATZ:")|(df['Person']=="COONS:")|(df['Person']=="JOHNSON:")|(df['Person']=="DURBIN:")|(df['Person']=="UDALL:")|(df['Person']=="CANTWELL:")|(df['Person']=="HELLER:")|(df['Person']=="CORNYN:")|(df['Person']=="LEAHY:")|(df['Person']=="LEE:")|(df['Person']=="KLOBUCHAR:")|(df['Person']=="BLUNT:")|(df['Person']=="FLAKE:")|(df['Person']=="MORAN:")|(df['Person']=="NELSON:")|(df['Person']=="WICKER:")|(df['Person']=="FEINSTEIN:")|(df['Person']=="HATCH:")]['Text'].tolist()
a=get_imp(S,mf=5000,ngram=5).head(10).sort_values(ascending=True)
a.index
# Out:
# Index(['zimbabwe just days ago met', 'facebook today guess people say',
#        'facebook tech companies engaged pervasive',
#        'facebook taken midday left worried',
#        'facebook social media platforms neutral',
#        'facebook share data does developer',
#        'facebook sent notification 87 million',
#        'facebook said strict limits information', '15 000 20 000 people',
#        'sorts legislative changes help solve'],
#       dtype='object')

# %%
xdr = ['zimbabwe just days ago met', 'facebook today guess people say',
       'facebook tech companies engaged pervasive',
       'facebook taken midday left worried',
       'facebook social media platforms neutral',
       'facebook share data does developer',
       'facebook sent notification 87 million',
       'facebook said strict limits information', '15 000 20 000 people',
       'sorts legislative changes help solve']
ydr = Range1d(0, 3)
plot5 = figure(
    x_range=ydr,
    y_range=xdr,
    plot_width=1100,
    plot_height=500,
    outline_line_color=None,
    toolbar_location=None, 
    min_border=20,
    x_axis_label='Number of times' ,
    y_axis_label='What all Senators Said in 5 words'
)

plot5.hbar(right=a.values,y=xdr,height=1,line_color="white",fill_color='#0000B2')
show(plot5)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f626af7a-54d3-4317-8f25-bb62f3a2dd52"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f626af7a-54d3-4317-8f25-bb62f3a2dd52");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f626af7a-54d3-4317-8f25-bb62f3a2dd52");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f626af7a-54d3-4317-8f25-bb62f3a2dd52' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"80894ca9-68da-4b0a-b86f-3511844d92ec":{"roots":{"references":[{"attributes":{},"id":"455bb8f5-d7f5-4c0d-ae3b-c385c4f4858e","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"f92b2c36-2813-44f2-a6ae-092c28098e9b","type":"Title"},{"attributes":{},"id":"0df0c524-0407-44e1-b3e3-2475312623f3","type":"CategoricalTickFormatter"},{"attributes":{},"id":"1f562d34-2cfb-47e1-8669-7eb611d5cb19","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"ed798e08-764a-4469-947a-62c132d21a94","subtype":"Figure","type":"Plot"}},"id":"76ae5656-a6b2-4eb4-b918-5cd546ba5e1f","type":"SaveTool"},{"attributes":{},"id":"36ce216e-6751-4701-9299-ce60d9d1f063","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2ff429ee-5757-49dc-b372-31c74f184556","type":"PanTool"},{"id":"b1f7613a-77e9-4e22-b91c-c8f20ca2217e","type":"WheelZoomTool"},{"id":"faaf2d4e-d3c2-4a3b-8533-6792c6c7ee4e","type":"BoxZoomTool"},{"id":"76ae5656-a6b2-4eb4-b918-5cd546ba5e1f","type":"SaveTool"},{"id":"a6696221-4d07-4aca-a322-2d5a9aa16408","type":"ResetTool"},{"id":"4e435eb9-bde6-4f19-bff6-ab319a8ea2fc","type":"HelpTool"}]},"id":"93e20162-f8b3-43b6-ae37-c54f12dd44a3","type":"Toolbar"},{"attributes":{"axis_label":"Number of times","formatter":{"id":"00001470-1a0c-439f-bf08-924a4fd3322f","type":"BasicTickFormatter"},"plot":{"id":"ed798e08-764a-4469-947a-62c132d21a94","subtype":"Figure","type":"Plot"},"ticker":{"id":"455bb8f5-d7f5-4c0d-ae3b-c385c4f4858e","type":"BasicTicker"}},"id":"504e38d7-46af-44f0-bbf3-69cb7c7e7a7a","type":"LinearAxis"},{"attributes":{"plot":{"id":"ed798e08-764a-4469-947a-62c132d21a94","subtype":"Figure","type":"Plot"}},"id":"b1f7613a-77e9-4e22-b91c-c8f20ca2217e","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"#0000B2"},"height":{"value":1},"line_color":{"value":"white"},"right":{"field":"right"},"y":{"field":"y"}},"id":"12776ad2-b067-408d-a67d-14407a60dd75","type":"HBar"},{"attributes":{"dimension":1,"plot":{"id":"ed798e08-764a-4469-947a-62c132d21a94","subtype":"Figure","type":"Plot"},"ticker":{"id":"1f562d34-2cfb-47e1-8669-7eb611d5cb19","type":"CategoricalTicker"}},"id":"4888049b-72ed-4bee-a450-b814c0d5bbba","type":"Grid"},{"attributes":{"axis_label":"What all Senators Said in 5 words","formatter":{"id":"0df0c524-0407-44e1-b3e3-2475312623f3","type":"CategoricalTickFormatter"},"plot":{"id":"ed798e08-764a-4469-947a-62c132d21a94","subtype":"Figure","type":"Plot"},"ticker":{"id":"1f562d34-2cfb-47e1-8669-7eb611d5cb19","type":"CategoricalTicker"}},"id":"da4f1e3a-e53c-4a32-be4e-a3a41215ddbe","type":"CategoricalAxis"},{"attributes":{"plot":{"id":"ed798e08-764a-4469-947a-62c132d21a94","subtype":"Figure","type":"Plot"}},"id":"2ff429ee-5757-49dc-b372-31c74f184556","type":"PanTool"},{"attributes":{},"id":"00001470-1a0c-439f-bf08-924a4fd3322f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"ed798e08-764a-4469-947a-62c132d21a94","subtype":"Figure","type":"Plot"}},"id":"a6696221-4d07-4aca-a322-2d5a9aa16408","type":"ResetTool"},{"attributes":{"callback":null,"factors":["zimbabwe just days ago met","facebook today guess people say","facebook tech companies engaged pervasive","facebook taken midday left worried","facebook social media platforms neutral","facebook share data does developer","facebook sent notification 87 million","facebook said strict limits information","15 000 20 000 people","sorts legislative changes help solve"]},"id":"75435ddd-dd18-4d6e-9593-314a9a567453","type":"FactorRange"},{"attributes":{"plot":{"id":"ed798e08-764a-4469-947a-62c132d21a94","subtype":"Figure","type":"Plot"},"ticker":{"id":"455bb8f5-d7f5-4c0d-ae3b-c385c4f4858e","type":"BasicTicker"}},"id":"170d0d83-207e-41db-8a5a-1d41a4b163fe","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"dce0fca1-2631-440f-a08d- ...

# %%
a=get_imp(S,mf=5000,ngram=3).head(10).sort_values(ascending=True)
a.index
# Out:
# Index(['want changes law', 'total information awareness',
#        '87 million facebook', 'campaign cambridge analytica',
#        '87 million users', 'decisions based political', 'going come strong',
#        'bug bounty program', '20 000 people', 'neutral public forum'],
#       dtype='object')

# %%
xdr = ['want changes law', 'total information awareness',
       '87 million facebook', 'campaign cambridge analytica',
       '87 million users', 'decisions based political', 'going come strong',
       'bug bounty program', '20 000 people', 'neutral public forum']
ydr = Range1d(0, 5)
plot6 = figure(
    x_range=ydr,
    y_range=xdr,
    plot_width=1100,
    plot_height=500,
    outline_line_color=None,
    toolbar_location=None, 
    min_border=20,
    x_axis_label='Number of times' ,
    y_axis_label='What all Senators Said in 3 words'
)

plot6.hbar(right=a.values,y=xdr,height=1,line_color="white",fill_color='#0000B2')
show(plot6)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7d37c5eb-a3b1-4f3c-8e1c-096773a07828"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7d37c5eb-a3b1-4f3c-8e1c-096773a07828");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7d37c5eb-a3b1-4f3c-8e1c-096773a07828");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7d37c5eb-a3b1-4f3c-8e1c-096773a07828' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"
type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"362be8bb-76ad-413d-a46f-803a8b8f541f","subtype":"Figure","type":"Plot"}},"id":"615a2326-ec5d-4b8f-a010-48cbe34398d2","type":"PanTool"},{"attributes":{"callback":null,"end":5},"id":"a3477c52-6823-4879-83bd-a632f91cf147","type":"Range1d"},{"attributes":{"axis_label":"Number of times","formatter":{"id":"8321863a-7062-4509-9b35-748999329d95","type":"BasicTickFormatter"},"plot":{"id":"362be8bb-76ad-413d-a46f-803a8b8f541f","subtype":"Figure","type":"Plot"},"ticker":{"i ...

# %%
a=get_imp(S,mf=5000,ngram=2).head(10).sort_values(ascending=True)
a.index
# Out:
# Index(['access data', 'business model', '000 people', 'don want', 'make sure',
#        'social media', 'terms service', '87 million', 'facebook users',
#        'cambridge analytica'],
#       dtype='object')

# %%
xdr = ['access data', 'business model', '000 people', 'don want', 'make sure',
       'social media', 'terms service', '87 million', 'facebook users',
       'cambridge analytica']
ydr = Range1d(0, 20)
plot6 = figure(
    x_range=ydr,
    y_range=xdr,
    plot_width=1100,
    plot_height=500,
    outline_line_color=None,
    toolbar_location=None, 
    min_border=20,
    x_axis_label='Number of times' ,
    y_axis_label='What all Senators Said in 2 words'
)

plot6.hbar(right=a.values,y=xdr,height=1,line_color="white",fill_color='#0000B2')
show(plot6)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cecfda6c-59c4-4d3d-8fd0-bc219f5dcac9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cecfda6c-59c4-4d3d-8fd0-bc219f5dcac9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cecfda6c-59c4-4d3d-8fd0-bc219f5dcac9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cecfda6c-59c4-4d3d-8fd0-bc219f5dcac9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f76cb2be-1458-4568-b1ca-cad81ebcb05e":{"roots":{"references":[{"attributes":{},"id":"18247fb3-9369-499b-8f5b-367e57deadfd","type":"BasicTicker"},{"attributes":{"plot":{"id":"568b1abc-2a56-4479-bdbf-669d45af94bf","subtype":"Figure","type":"Plot"}},"id":"586d34ee-6d9e-4597-9c8f-2ea568bbdbb7","type":"SaveTool"},{"attributes":{"plot":{"id":"568b1abc-2a56-4479-bdbf-669d45af94bf","subtype":"Figure","type":"Plot"},"ticker":{"id":"18247fb3-9369-499b-8f5b-367e57deadfd","type":"BasicTicker"}},"id":"23e9c5d0-3f83-4548-9670-875135bc625f","type":"Grid"},{"attributes":{"axis_label":"What all Senators Said in 2 words","formatter":{"id":"a32fc7c0-5a30-4eb1-b3aa-027024f304e3","type":"CategoricalTickFormatter"},"plot":{"id":"568b1abc-2a56-4479-bdbf-669d45af94bf","subtype":"Figure","type":"Plot"},"ticker":{"id":"d07d5fc8-8059-46ec-8ff6-72e077ba32f0","type":"CategoricalTicker"}},"id":"775f21cc-1913-400f-b6ca-4399a211142f","type":"CategoricalAxis"},{"attributes":{},"id":"a7c4280f-5637-4b90-aaaf-288ceed5806f","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a20db29f-d8ce-4ed0-8e89-fb416919e6ba","type":"PanTool"},{"id":"c589f40b-efc7-47f8-9177-4f95ef18c4bb","type":"WheelZoomTool"},{"id":"e012f3c4-84cf-4d04-a585-2c6ec4aab0f5","type":"BoxZoomTool"},{"id":"586d34ee-6d9e-4597-9c8f-2ea568bbdbb7","type":"SaveTool"},{"id":"9a420b9e-7227-487e-b9f1-214f8da91d4d","type":"ResetTool"},{"id":"2fa8daa7-7639-4239-ad8d-6533793f4ffc","type":"HelpTool"}]},"id":"d7033543-3503-4d91-8a38-6b77c45d7363","type":"Toolbar"},{"attributes":{"callback":null,"factors":["access data","business model","000 people","don want","make sure","social media","terms service","87 million","facebook users","cambridge analytica"]},"id":"4ae5af09-28e9-4c6e-899b-23f18384711b","type":"FactorRange"},{"attributes":{"callback":null,"end":20},"id":"316bfb71-f90c-45bf-8e43-9e9adb6e0da8","type":"Range1d"},{"attributes":{"below":[{"id":"06fc9ad2-ddcb-49c4-9bef-cda0d53bd159","type":"LinearAxis"}],"left":[{"id":"775f21cc-1913-400f-b6ca-4399a211142f","type":"CategoricalAxis"}],"min_border":20,"outline_line_color":{"value":null},"plot_height":500,"plot_width":1100,"renderers":[{"id":"06fc9ad2-ddcb-49c4-9bef-cda0d53bd159","type":"LinearAxis"},{"id":"23e9c5d0-3f83-4548-9670-875135bc625f","type":"Grid"},{"id":"775f21cc-1913-400f-b6ca-4399a211142f","type":"CategoricalAxis"},{"id":"f28c8d22-bbf8-4261-889b-f79cec259fcd","type":"Grid"},{"id":"1230efb6-2053-4225-98fe-27bf849fdb4a","type":"BoxAnnotation"},{"id":"dcbcb029-a5e4-41c0-b0e0-e4d79c661463","type":"GlyphRenderer"}],"title":{"id":"08047767-9299-4f0e-918b-bc5a6f0aff74","type":"Title"},"tool_events":{"id":"a7c4280f-5637-4b90-aaaf-288ceed5806f","type":"ToolEvents"},"toolbar":{"id":"d7033543-3503-4d91-8a38-6b77c45d7363","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"316bfb71-f90c-45bf-8e43-9e9adb6e0da8","type":"Range1d"},"y_range":{"id":"4ae5af09-28e9-4c6e-899b-23f18384711b","type":"FactorRange"}},"id":"568b1abc-2a56-4479-bdbf-669d45af94bf","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"#0000B2"},"height":{"value":1},"line_color":{"value":"white"},"right":{"field":"right"},"y":{"field":"y"}},"id":"ae02b9fa-789d-4445-a8d7-dc069296683d","type":"HBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"b1951a7b-cec0-49bd-8200-1b73498bd72f","type":"HBar"},{"attributes":{},"id":"a32fc7c0-5a30-4eb1-b3aa-027024f304e3","type":"CategoricalTickFormatter"},{"attributes":{},"id":"d07d5fc8-8059-46ec-8ff6-72e077ba32f0","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["y","right"],"data":{"right":[4,4,5,5,6,6,8,9,12,17],"y":["access data","business model","000 people","don want","make sure","social media","terms service","87 million","facebook users","cambridge ana ...

# %% [markdown]
# #### Sentiment Analysis

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
analize_sentiment(df['Text'].iloc[0])
# Out:
# 1

# %%
clean_tweet(df['Text'].iloc[0])
# Out:
# 'I ll start with you Facebook handles extensive amounts of personal data for billions of users A significant amount of that data is shared with third party developers who utilize your platform As of this early this year you did not actively monitor whether that data was transferred by such developers to other parties Moreover your policies only prohibit transfers by developers to parties seeking to profit from such data Number one besides Professor Kogan s transfer and now potentially Cubeyou do you know of any instances where user data was improperly transferred to third party in breach of Facebook s terms If so how many times has that happened and was Facebook only made aware of that transfer by some third party'

# %%
df.shape
# Out:
# (858, 3)

# %%
df['sentiment']="Other"
for i in range(0,853):
    analysis = TextBlob(clean_tweet(df['Text'].iloc[i]))
    if analysis.sentiment.polarity > 0:
        df['sentiment'].iloc[i]='Positive'
    elif analysis.sentiment.polarity == 0:
        df['sentiment'].iloc[i]='Negative'
    else:
        df['sentiment'].iloc[i]='Neutral'
# Out:
# C:\Users\moham\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['sentiment'].value_counts()
# Out:
# Positive    439
# Negative    319
# Neutral      95
# Other         5
# Name: sentiment, dtype: int64

# %%
df["Text"].loc[df['sentiment']=='Negative'][68]
# Out:
# " So they may have been involved and all working together during that time period? Maybe that's something your investigation will find out.\n\n"

# %%
stopwords=set(STOPWORDS).union(ENGLISH_STOP_WORDS).union('senator')
#alice_mask = np.array(Image.open("../input/fbmask/fbmask.png"))
names = df["Text"].loc[df['sentiment']=='Positive']
#print(names)
wordcloud = WordCloud(max_words=150,stopwords=stopwords,max_font_size=70, width=800, height=300,#mask=alice_mask,
                      background_color ="white").generate(' '.join(names))
plt.figure(figsize=(15,8))
plt.imshow(wordcloud,interpolation="bilinear")
plt.title("Words said in a statement with a positive sentiment", fontsize=30)
plt.axis("off")
plt.savefig("mark",dpi=600)
plt.show()

# %%
stopwords=set(STOPWORDS).union(ENGLISH_STOP_WORDS).union('Senator')
#alice_mask = np.array(Image.open("../input/fbmask/fbmask.png"))
names = df["Text"].loc[df['sentiment']=='Negative']
#print(names)
wordcloud = WordCloud(max_words=150,stopwords=stopwords,max_font_size=70, width=800, height=300,#mask=alice_mask,
                      background_color ="white").generate(' '.join(names))
plt.figure(figsize=(15,8))
plt.imshow(wordcloud,interpolation="bilinear")
plt.title("Words said in a statement with a negative sentiment", fontsize=30)
plt.axis("off")
plt.savefig("mark",dpi=600)
plt.show()

# %%
ndf=df.loc[df['sentiment']=='Negative']
S=ndf[(ndf['Person']=="CRUZ:")|(ndf['Person']=="WHITEHOUSE:")|(ndf['Person']=="WHITEHOUSE:")|(ndf['Person']=="SCHATZ:")|(ndf['Person']=="COONS:")|(ndf['Person']=="JOHNSON:")|(ndf['Person']=="DURBIN:")|(ndf['Person']=="UDALL:")|(ndf['Person']=="CANTWELL:")|(ndf['Person']=="HELLER:")|(ndf['Person']=="CORNYN:")|(ndf['Person']=="LEAHY:")|(ndf['Person']=="LEE:")|(ndf['Person']=="KLOBUCHAR:")|(ndf['Person']=="BLUNT:")|(ndf['Person']=="FLAKE:")|(ndf['Person']=="MORAN:")|(ndf['Person']=="NELSON:")|(ndf['Person']=="WICKER:")|(ndf['Person']=="FEINSTEIN:")|(ndf['Person']=="HATCH:")]['Text']

# %%
stopwords=set(STOPWORDS).union(ENGLISH_STOP_WORDS)
#alice_mask = np.array(Image.open("../input/fbmask/fbmask.png"))
names = S
#print(names)
wordcloud = WordCloud(max_words=150,stopwords=stopwords,max_font_size=70, width=800, height=300,#mask=alice_mask,
                      background_color ="white").generate(' '.join(names))
plt.figure(figsize=(15,8))
plt.imshow(wordcloud,interpolation="bilinear")
plt.title("words said by Senators in a negative sentiment", fontsize=30)
plt.axis("off")
plt.savefig("mark",dpi=600)
plt.show()
